# %%
import pandas as pd
import numpy as np
import matplotlib
import datetime

import matplotlib.pyplot as plt

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
aapl = pd.read_csv('datasets/AAPL.csv')

aapl.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2010-09-01  35.352856  35.922855  35.182858  35.761429  31.209463
# 1  2010-09-02  35.894287  36.024284  35.509998  36.024284  31.438864
# 2  2010-09-03  36.441429  36.968571  36.357143  36.967144  32.261719
# 3  2010-09-07  36.662857  37.075714  36.607143  36.830002  32.142021
# 4  2010-09-08  37.111427  37.770000  37.014286  37.560001  32.779102
#
#       Volume
# 0  174259400
# 1  103856900
# 2  130197200
# 3   85639400
# 4  131637800

# %%
aapl = aapl.sample(frac=1)

aapl.reset_index(inplace=True, drop=True)

aapl.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-01  113.459999  113.769997  110.529999  111.489998  106.276443
# 1  2014-08-08   94.260002   94.820000   93.279999   94.739998   86.933136
# 2  2013-11-21   73.942856   74.458572   73.381432   74.448570   67.195892
# 3  2012-03-22   85.397141   86.357140   85.075714   85.620003   74.721718
# 4  2019-05-29  176.419998  179.350006  176.000000  177.380005  176.708603
#
#       Volume
# 0   43825800
# 1   41865000
# 2   65506700
# 3  155967700
# 4   28481200

# %%
aapl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2265 entries, 0 to 2264
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2265 non-null   object
#  1   Open       2265 non-null   float64
#  2   High       2265 non-null   float64
#  3   Low        2265 non-null   float64
#  4   Close      2265 non-null   float64
#  5   Adj Close  2265 non-null   float64
#  6   Volume     2265 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 124.0+ KB

# %%
aapl['Date'] = pd.to_datetime(aapl['Date'])

aapl.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2016-11-01  113.459999  113.769997  110.529999  111.489998  106.276443
# 1 2014-08-08   94.260002   94.820000   93.279999   94.739998   86.933136
# 2 2013-11-21   73.942856   74.458572   73.381432   74.448570   67.195892
# 3 2012-03-22   85.397141   86.357140   85.075714   85.620003   74.721718
# 4 2019-05-29  176.419998  179.350006  176.000000  177.380005  176.708603
#
#       Volume
# 0   43825800
# 1   41865000
# 2   65506700
# 3  155967700
# 4   28481200

# %%
aapl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2265 entries, 0 to 2264
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2265 non-null   datetime64[ns]
#  1   Open       2265 non-null   float64
#  2   High       2265 non-null   float64
#  3   Low        2265 non-null   float64
#  4   Close      2265 non-null   float64
#  5   Adj Close  2265 non-null   float64
#  6   Volume     2265 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 124.0 KB

# %%
aapl.shape
# Out:
# (2265, 7)

# %%
aapl.sort_values(by='Date', inplace=True)

aapl.head()
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 1960 2010-09-01  35.352856  35.922855  35.182858  35.761429  31.209463
# 217  2010-09-02  35.894287  36.024284  35.509998  36.024284  31.438864
# 912  2010-09-03  36.441429  36.968571  36.357143  36.967144  32.261719
# 1978 2010-09-07  36.662857  37.075714  36.607143  36.830002  32.142021
# 325  2010-09-08  37.111427  37.770000  37.014286  37.560001  32.779102
#
#          Volume
# 1960  174259400
# 217   103856900
# 912   130197200
# 1978   85639400
# 325   131637800

# %%
aapl.reset_index(inplace=True, drop=True)

aapl.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close     Volume
# 0 2010-09-01  35.352856  35.922855  35.182858  35.761429  31.209463  174259400
# 1 2010-09-02  35.894287  36.024284  35.509998  36.024284  31.438864  103856900
# 2 2010-09-03  36.441429  36.968571  36.357143  36.967144  32.261719  130197200
# 3 2010-09-07  36.662857  37.075714  36.607143  36.830002  32.142021   85639400
# 4 2010-09-08  37.111427  37.770000  37.014286  37.560001  32.779102  131637800

# %%
aapl['Date'] = aapl['Date'].apply(lambda d: d.to_pydatetime())

aapl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2265 entries, 0 to 2264
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2265 non-null   datetime64[ns]
#  1   Open       2265 non-null   float64
#  2   High       2265 non-null   float64
#  3   Low        2265 non-null   float64
#  4   Close      2265 non-null   float64
#  5   Adj Close  2265 non-null   float64
#  6   Volume     2265 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 124.0 KB

# %%
aapl['Weekday'] = aapl['Date'].apply(lambda d: d.isoweekday())

aapl.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close  \
# 0 2010-09-01  35.352856  35.922855  35.182858  35.761429  31.209463
# 1 2010-09-02  35.894287  36.024284  35.509998  36.024284  31.438864
# 2 2010-09-03  36.441429  36.968571  36.357143  36.967144  32.261719
# 3 2010-09-07  36.662857  37.075714  36.607143  36.830002  32.142021
# 4 2010-09-08  37.111427  37.770000  37.014286  37.560001  32.779102
#
#       Volume  Weekday
# 0  174259400        3
# 1  103856900        4
# 2  130197200        5
# 3   85639400        2
# 4  131637800        3

# %%
extract_year = lambda x: datetime.datetime.strptime(str(x), "%Y-%m-%d %H:%M:%S").year

# %%
aapl['Year'] = aapl['Date'].apply(extract_year)

aapl.sample(10)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 71   2010-12-13   46.338570   46.437141   45.857143   45.952858   40.103664
# 1469 2016-07-05   95.389999   95.400002   94.459999   94.989998   90.060150
# 364  2012-02-10   70.137146   71.088570   69.792854   70.488571   61.516300
# 1565 2016-11-17  109.809998  110.349998  108.830002  109.949997  105.346558
# 1924 2018-04-25  162.619995  165.419998  162.410004  163.649994  159.969269
# 880  2014-03-04   75.857140   76.091431   75.395714   75.891426   68.908203
# 2070 2018-11-20  178.369995  181.470001  175.509995  176.979996  174.883713
# 2060 2018-11-06  201.919998  204.720001  201.690002  203.770004  200.656265
# 273  2011-09-30   55.302856   55.555714   54.454285   54.474285   47.540436
# 2093 2018-12-26  148.300003  157.229996  146.720001  157.169998  155.308350
#
#          Volume  Weekday  Year
# 71    109953900        1  2010
# 1469   27705200        2  2016
# 364   157825500        5  2012
# 1565   27632000        4  2016
# 1924   28382100        3  2018
# 880    64785000        2  2014
# 2070   67825200        2  2018
# 2060   31882900        2  2018
# 273   136910200        5  2011
# 2093   58582500        3  2018

# %%
extract_month = lambda x: datetime.datetime.strptime(str(x), "%Y-%m-%d %H:%M:%S").month

# %%
aapl['Month'] = aapl['Date'].apply(extract_month)

aapl.sample(10)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 912  2014-04-17   74.285713   75.394287   74.171425   74.991432   68.091019
# 925  2014-05-07   85.035713   85.327141   83.961426   84.618568   76.832321
# 419  2012-05-01   83.557144   85.251427   83.032860   83.161430   72.576073
# 432  2012-05-18   76.279999   77.629997   74.597145   75.768570   66.124229
# 1773 2017-09-18  160.110001  160.500000  158.000000  158.669998  153.918137
# 1749 2017-08-14  159.320007  160.210007  158.750000  159.850006  155.062820
# 880  2014-03-04   75.857140   76.091431   75.395714   75.891426   68.908203
# 1369 2016-02-10   95.919998   96.349998   94.099998   94.269997   88.836655
# 1788 2017-10-09  155.809998  156.729996  155.490005  155.839996  151.172897
# 1443 2016-05-26   99.680000  100.730003   98.639999  100.410004   95.198868
#
#          Volume  Weekday  Year  Month
# 912    71083600        4  2014      4
# 925    70716100        3  2014      5
# 419   152749800        2  2012      5
# 432   183073100        5  2012      5
# 1773   28269400        1  2017      9
# 1749   22122700        1  2017      8
# 880    64785000        2  2014      3
# 1369   42343600        3  2016      2
# 1788   16262900        1  2017     10
# 1443   56331200        4  2016      5

# %%
plt.figure(figsize=(10, 8))

plt.plot(aapl['Date'], 
         aapl['Close'])


plt.xlabel('Date')
plt.ylabel('AAPL stock price')

plt.show()

# %%
aapl_by_month = aapl.groupby(by='Month').mean()

aapl_by_month
# Out:
#              Open        High         Low       Close   Adj Close  \
# Month
# 1      101.994535  102.918907  100.951405  101.984114   95.751760
# 2      105.731883  106.824278  104.926416  105.957919   99.758569
# 3      110.966491  111.905912  109.954652  110.932645  104.567909
# 4      113.209677  114.178134  112.210968  113.190253  106.801941
# 5      114.985700  116.054071  114.072117  115.136299  109.015417
# 6      114.861189  115.727824  113.905445  114.763380  108.690969
# 7      118.451053  119.374985  117.628308  118.553113  112.321209
# 8      123.594762  124.837491  122.504158  123.739922  117.636038
# 9      106.138392  107.083427  105.041077  106.015301   99.328919
# 10     108.965033  110.002988  107.843502  108.991740  102.258505
# 11     106.816479  107.740888  105.663429  106.738062  100.328575
# 12     102.733192  103.636634  101.636406  102.549392   96.163693
#
#              Volume   Weekday         Year
# Month
# 1      7.937537e+07  3.109290  2015.016393
# 2      7.453773e+07  3.092486  2014.988439
# 3      7.219678e+07  3.010256  2014.979487
# 4      7.514483e+07  2.903226  2015.005376
# 5      6.305513e+07  3.103627  2015.020725
# 6      5.563672e+07  3.020942  2014.984293
# 7      5.575913e+07  2.957895  2015.010526
# 8      6.634713e+07  3.029851  2015.000000
# 9      8.456097e+07  3.114754  2013.967213
# 10     8.016695e+07  2.989848  2014.050761
# 11     7.033131e+07  2.962162  2014.000000
# 12     6.463759e+07  3.021277  2013.936170

# %%
plt.figure(figsize=(10, 8))

plt.plot(aapl_by_month.index, 
         aapl_by_month['Close'])


plt.xlabel('Date')
plt.ylabel('AAPL stock price')

plt.show()
