# %% [markdown]
# # Installing libraries

# %%
# !pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 8.3 MB/s
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.20-cp38-cp38-macosx_10_9_x86_64.whl (19.3 MB)
#      |████████████████████████████████| 19.3 MB 11.8 MB/s
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.2.1-cp38-cp38-macosx_10_9_x86_64.whl (7.5 MB)
#      |████████████████████████████████| 7.5 MB 5.8 MB/s
# Requirement already satisfied: pandas>=0.25.0 in /Users/tatsuya.fujisaki/opt/anaconda3/lib/python3.8/site-packages (from geopandas) (1.3.2)
# Collecting shapely>=1.6
#   Downloading Shapely-1.7.1-cp38-cp38-macosx_10_9_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 15.0 MB/s
# Requirement already satisfied: setuptools in /Users/tatsuya.fujisaki/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (52.0.0.post20210125)
# Requirement already satisfied: click>=4.0 in /Users/tatsuya.fujisaki/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (8.0.1)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: six>=1.7 in /Users/tatsuya.fujisaki/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: certifi in /Users/tatsuya.fujisaki/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2021.10.8)
# Requirement already satisfied: attrs>=17 in /Users/tatsuya.fujisaki/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (21.2.0)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: numpy>=1.17.3 in /Users/tatsuya.fujisaki/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25.0->geopandas) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/tatsuya.fujisaki/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/tatsuya.fujisaki/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25.0->geopandas) (2021.1)
# Installing collected packages: munch, cligj, click-plugins, shapely, pyproj, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.20 geopandas-0.10.2 munch-2.5.0 pyproj-3.2.1 shapely-1.7.1

# %%
# !pip install descartes
# Out:
# Collecting descartes
#   Downloading descartes-1.1.0-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: matplotlib in /Users/tatsuya.fujisaki/opt/anaconda3/lib/python3.8/site-packages (from descartes) (3.4.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/tatsuya.fujisaki/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->descartes) (8.3.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/tatsuya.fujisaki/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->descartes) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/tatsuya.fujisaki/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->descartes) (0.10.0)
# Requirement already satisfied: numpy>=1.16 in /Users/tatsuya.fujisaki/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->descartes) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/tatsuya.fujisaki/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->descartes) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/tatsuya.fujisaki/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->descartes) (2.4.7)
# Requirement already satisfied: six in /Users/tatsuya.fujisaki/opt/anaconda3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib->descartes) (1.15.0)
# Installing collected packages: descartes
# Successfully installed descartes-1.1.0

# %% [markdown]
# # Introduction to geospatial vector data in python
#
# #### Geospatial [Data](http://www.naturalearthdata.com/downloads/110m-cultural-vectors/110m-admin-0-countries/) , or spatial data (as it's sometimes known), is information that has a geographic aspect to it. In other words, the records in this type of information set have coordinates, an address, city, postal code, or zip code included with them. The most obvious example is a road map. We see the rendered result, but the features on the map are stored with this type of information included in them.
#
# There are two basic types or forms of geospatial data:
#
# * Vector - This form uses points, lines, and polygons to represent spatial features such as cities, roads, and streams.
#
# * Raster - This form uses cells (computers often use dots or pixels) to represent spatial features. Cities are single cells, roads are linear sequences of cells, and streams are collections of adjacent cells. An example of this is remote satellite data.

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd

import matplotlib.pyplot as plt
import geopandas

pd.options.display.max_rows = 10

# %%
df = pd.DataFrame(
    {'City': ['Buenos Aires', 'Brasilia', 'Santiago', 'Bogota', 'Caracas'],
     'Country': ['Argentina', 'Brazil', 'Chile', 'Colombia', 'Venezuela'],
     'Latitude': [-34.58, -15.78, -33.45, 4.60, 10.48],
     'Longitude': [-58.66, -47.91, -70.66, -74.08, -66.86]})

df.head()
# Out:
#            City    Country  Latitude  Longitude
# 0  Buenos Aires  Argentina    -34.58     -58.66
# 1      Brasilia     Brazil    -15.78     -47.91
# 2      Santiago      Chile    -33.45     -70.66
# 3        Bogota   Colombia      4.60     -74.08
# 4       Caracas  Venezuela     10.48     -66.86

# %%
gdf = geopandas.GeoDataFrame(
    df, geometry=geopandas.points_from_xy(df.Longitude, df.Latitude))

# %%
gdf.head()
# Out:
#            City    Country  Latitude  Longitude                     geometry
# 0  Buenos Aires  Argentina    -34.58     -58.66  POINT (-58.66000 -34.58000)
# 1      Brasilia     Brazil    -15.78     -47.91  POINT (-47.91000 -15.78000)
# 2      Santiago      Chile    -33.45     -70.66  POINT (-70.66000 -33.45000)
# 3        Bogota   Colombia      4.60     -74.08    POINT (-74.08000 4.60000)
# 4       Caracas  Venezuela     10.48     -66.86   POINT (-66.86000 10.48000)

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

ax = world[world.continent == 'South America'].plot(
    color='white', edgecolor='black')

gdf.plot(ax=ax, color='red')

plt.show()

# %% [markdown]
# # Importing geospatial data

# %%
countries = geopandas.read_file('datasets/data/ne_110m_admin_0_countries.shp')

# %%
countries.head()
# Out:
#         featurecla  scalerank  LABELRANK                   SOVEREIGNT SOV_A3  \
# 0  Admin-0 country          1          6                         Fiji    FJI
# 1  Admin-0 country          1          3  United Republic of Tanzania    TZA
# 2  Admin-0 country          1          7               Western Sahara    SAH
# 3  Admin-0 country          1          2                       Canada    CAN
# 4  Admin-0 country          1          2     United States of America    US1
#
#    ADM0_DIF  LEVEL               TYPE                        ADMIN ADM0_A3  \
# 0         0      2  Sovereign country                         Fiji     FJI
# 1         0      2  Sovereign country  United Republic of Tanzania     TZA
# 2         0      2      Indeterminate               Western Sahara     SAH
# 3         0      2  Sovereign country                       Canada     CAN
# 4         1      2            Country     United States of America     USA
#
#    ...  NAME_KO                       NAME_NL            NAME_PL  \
# 0  ...       피지                          Fiji              Fidżi
# 1  ...     탄자니아                      Tanzania           Tanzania
# 2  ...     서사하라             Westelijke Sahara   Sahara Zachodnia
# 3  ...      캐나다                        Canada             Kanada
# 4  ...       미국  Verenigde Staten van Amerika  Stany Zjednoczone
#
#            NAME_PT                    NAME_RU     NAME_SV  \
# 0             Fiji                      Фиджи        Fiji
# 1         Tanzânia                   Танзания    Tanzania
# 2  Saara Ocidental            Западная Сахара  Västsahara
# 3           Canadá                     Канада      Kanada
# 4   Estados Unidos  Соединённые Штаты Америки         USA
#
#                        NAME_TR     NAME_VI NAME_ZH  \
# 0                         Fiji        Fiji      斐濟
# 1                     Tanzanya    Tanzania    坦桑尼亚
# 2                   Batı Sahra  Tây Sahara    西撒哈拉
# 3                       Kanada      Canada     加拿大
# 4  Amerika Birleşik Devletleri      Hoa Kỳ      美国
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
#
# [5 rows x 95 columns]

# %% [markdown]
# ### Data type of geospatial data

# %%
type(countries)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# ### Plot countries polygon
# GeoDataFrame objects include a plot method

# %%
countries.plot(figsize=(15, 8))

plt.show()

# %% [markdown]
# ### This is geometry of geospatial data
# Each country is a polygon in the map

# %%
countries['geometry']
# Out:
# 0      MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1      POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2      POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3      MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4      MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
#                              ...
# 172    POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173    POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 174    POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175    POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176    POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
# Name: geometry, Length: 177, dtype: geometry

# %% [markdown]
# #### View the geometry of Tanzania
# It's quite a complex polygon

# %%
print(countries.geometry[1])
# Out:
# POLYGON ((33.90371119710453 -0.9500000000000001, 34.07261999999997 -1.059819999999945, 37.69868999999994 -3.096989999999948, 37.7669 -3.67712, 39.20222 -4.67677, 38.74053999999995 -5.908949999999948, 38.79977000000008 -6.475660000000005, 39.44 -6.839999999999861, 39.47000000000014 -7.099999999999966, 39.19468999999998 -7.703899999999976, 39.25203000000005 -8.007809999999949, 39.18652000000009 -8.48550999999992, 39.53574000000009 -9.112369999999885, 39.94960000000003 -10.09840000000003, 40.31658622911085 -10.31709775281749, 40.31659000000002 -10.31709999999987, 39.52099999999996 -10.89688000000001, 38.42755659358775 -11.28520232508166, 37.82763999999997 -11.26878999999991, 37.47128999999995 -11.56876, 36.77515099462281 -11.59453744878081, 36.51408165868426 -11.72093800216673, 35.31239790216904 -11.43914641687915, 34.55998904799935 -11.52002003341592, 34.27999999999997 -10.16000000000003, 33.94083772409653 -9.693673841980285, 33.73972000000009 -9.417149999999992, 32.75937544122132 -9.23059905358906, 32.19186486179194 -8.930358981973257, 31.5563480974665 -8.762048841998642, 31.15775133695005 -8.594578747317366, 30.7400097314221 -8.340005930353721, 30.74001549655179 -8.340007419470915, 30.1999967791017 -7.079980970898163, 29.62003217949001 -6.520015150583426, 29.41999271008817 -5.939998874539434, 29.51998660657293 -5.419978936386315, 29.33999759290035 -4.499983412294092, 29.75351240409987 -4.452389418153302, 30.11632000000003 -4.090120000000013, 30.50554 -3.56857999999994, 30.75224000000009 -3.359309999999994, 30.74301000000003 -3.034309999999948, 30.52766000000003 -2.807619999999986, 30.46967364576122 -2.41385475710134, 30.46967000000001 -2.413829999999962, 30.75830895358311 -2.287250257988369, 30.81613488131771 -1.698914076345389, 30.41910485201925 -1.134659112150416, 30.76986000000011 -1.014549999999986, 31.86617000000007 -1.027359999999931, 33.90371119710453 -0.9500000000000001))

# %% [markdown]
# ### This is geometric area
# The first country at index 0 is Fiji (which is tiny). The countries at index 3 and 4 are Canada and the USA.

# %%
countries['geometry'].area
# Out:
# /var/folders/hr/lhymn9jx7n9344wbdg0dp04h32f3tk/T/ipykernel_21175/1728538982.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   countries['geometry'].area
# 0         1.639511
# 1        76.301964
# 2         8.603984
# 3      1712.995228
# 4      1122.281921
#           ...
# 172       8.604719
# 173       1.479321
# 174       1.231641
# 175       0.639000
# 176      51.196106
# Length: 177, dtype: float64

# %% [markdown]
# ### Look the names of columns

# %%
countries.columns
# Out:
# Index(['featurecla', 'scalerank', 'LABELRANK', 'SOVEREIGNT', 'SOV_A3',
#        'ADM0_DIF', 'LEVEL', 'TYPE', 'ADMIN', 'ADM0_A3', 'GEOU_DIF', 'GEOUNIT',
#        'GU_A3', 'SU_DIF', 'SUBUNIT', 'SU_A3', 'BRK_DIFF', 'NAME', 'NAME_LONG',
#        'BRK_A3', 'BRK_NAME', 'BRK_GROUP', 'ABBREV', 'POSTAL', 'FORMAL_EN',
#        'FORMAL_FR', 'NAME_CIAWF', 'NOTE_ADM0', 'NOTE_BRK', 'NAME_SORT',
#        'NAME_ALT', 'MAPCOLOR7', 'MAPCOLOR8', 'MAPCOLOR9', 'MAPCOLOR13',
#        'POP_EST', 'POP_RANK', 'GDP_MD_EST', 'POP_YEAR', 'LASTCENSUS',
#        'GDP_YEAR', 'ECONOMY', 'INCOME_GRP', 'WIKIPEDIA', 'FIPS_10_', 'ISO_A2',
#        'ISO_A3', 'ISO_A3_EH', 'ISO_N3', 'UN_A3', 'WB_A2', 'WB_A3', 'WOE_ID',
#        'WOE_ID_EH', 'WOE_NOTE', 'ADM0_A3_IS', 'ADM0_A3_US', 'ADM0_A3_UN',
#        'ADM0_A3_WB', 'CONTINENT', 'REGION_UN', 'SUBREGION', 'REGION_WB',
#        'NAME_LEN', 'LONG_LEN', 'ABBREV_LEN', 'TINY', 'HOMEPART', 'MIN_ZOOM',
#        'MIN_LABEL', 'MAX_LABEL', 'NE_ID', 'WIKIDATAID', 'NAME_AR', 'NAME_BN',
#        'NAME_DE', 'NAME_EN', 'NAME_ES', 'NAME_FR', 'NAME_EL', 'NAME_HI',
#        'NAME_HU', 'NAME_ID', 'NAME_IT', 'NAME_JA', 'NAME_KO', 'NAME_NL',
#        'NAME_PL', 'NAME_PT', 'NAME_RU', 'NAME_SV', 'NAME_TR', 'NAME_VI',
#        'NAME_ZH', 'geometry'],
#       dtype='object')

# %% [markdown]
# ### This is average population number over all countries
#
# __Note:-  The columns `POP_EST` contains records of population of each country__

# %%
countries[['NAME_EN', 'POP_EST', 'INCOME_GRP']].head()
# Out:
#                     NAME_EN    POP_EST              INCOME_GRP
# 0                      Fiji     920938  4. Lower middle income
# 1                  Tanzania   53950935           5. Low income
# 2            Western Sahara     603253           5. Low income
# 3                    Canada   35623680    1. High income: OECD
# 4  United States of America  326625791    1. High income: OECD

# %% [markdown]
# ### Take Asia's polygon geometry and view

# %%
asia = countries[countries['CONTINENT'] == 'Asia']

# %%
asia.plot(figsize=(12, 6))
plt.show()

# %% [markdown]
# ## Geometries: Points, Linestrings, and Polygons
# __Spatial vector data can consist of different types and three fundamental types are:-__
# * __Point__ data: represents a single point in space
# * __Line__ data(LineString data): represents a sequence of points that form of line
# * __Polygon__ data: represents a filled area

# %% [markdown]
# ### Let's import some other datasets with different types of geometric objects

# %% [markdown]
# A [datasets](http://www.naturalearthdata.com/downloads/110m-cultural-vectors/110m-populated-places/) about cities in the world

# %% [markdown]
# ### Load and read geospatial data of cities

# %%
cities = geopandas.read_file('zip://datasets/ne_110m_populated_places.zip')

# %%
type(cities)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# ### View 10 sample

# %%
cities.tail(10)
# Out:
#      SCALERANK  NATSCALE  LABELRANK              FEATURECLA            NAME  \
# 233          0       600          2         Admin-0 capital           Tokyo
# 234          0       600          1         Admin-1 capital          Mumbai
# 235          0       600          3         Admin-0 capital           Paris
# 236          0       600          3         Admin-0 capital        Santiago
# 237          0       600          1         Admin-1 capital         Kolkata
# 238          0       600          1         Admin-1 capital  Rio de Janeiro
# 239          0       600          1         Admin-1 capital       São Paulo
# 240          0       600          3         Admin-1 capital          Sydney
# 241          0       600          0         Admin-0 capital       Singapore
# 242          0       600          0  Admin-0 region capital       Hong Kong
#
#       NAMEPAR              NAMEALT  DIFFASCII       NAMEASCII  ADM0CAP  ...  \
# 233      None                 None          0           Tokyo      1.0  ...
# 234    Bombay                 None          0          Mumbai      0.0  ...
# 235      None                 None          0           Paris      1.0  ...
# 236      None                 None          0        Santiago      1.0  ...
# 237  Calcutta                 None          0         Kolkata      0.0  ...
# 238      None                 None          0  Rio de Janeiro      0.0  ...
# 239      None  Sao Paulo|Sio Paulo          0       Sao Paulo      0.0  ...
# 240      None                 None          0          Sydney      0.0  ...
# 241      None                 None          0       Singapore      1.0  ...
# 242      None                 None          0       Hong Kong      0.0  ...
#
#       name_ja  name_ko         name_nl         name_pl            name_sv  \
# 233       東京都      도쿄도           Tokio           Tokio    Tokyo prefektur
# 234      ムンバイ      뭄바이          Bombay          Mumbaj             Bombay
# 235        パリ       파리          Parijs           Paryż              Paris
# 236    サンティアゴ     산티아고        Santiago        Santiago  Santiago de Chile
# 237      コルカタ      콜카타        Calcutta         Kolkata           Calcutta
# 238  リオデジャネイロ  리우데자네이루  Rio de Janeiro  Rio de Janeiro     Rio de Janeiro
# 239     サンパウロ     상파울루       São Paulo       São Paulo          São Paulo
# 240      シドニー      시드니          Sydney          Sydney             Sydney
# 241    シンガポール     싱가포르       Singapore        Singapur          Singapore
# 242        香港       홍콩        Hongkong        Hongkong           Hongkong
#
#             name_tr            name_vi wdid_score       ne_id  \
# 233           Tokyo              Tokyo          4  1159151609
# 234          Mumbai             Mumbai          4  1159151611
# 235           Paris              Paris          4  1159151613
# 236        Santiago  Santiago de Chile          4  1159151615
# 237         Kalküta            Kolkata          4  1159151617
# 238  Rio de Janeiro     Rio de Janeiro          4  1159151619
# 239       São Paulo          São Paulo          4  1159151621
# 240          Sidney             Sydney          4  1159151623
# 241        Singapur          Singapore          4  1159151627
# 242       Hong Kong          Hồng Kông          4  1159151629
#
#                         geometry
# 233   POINT (139.74946 35.68696)
# 234    POINT (72.85504 19.01894)
# 235     POINT (2.33139 48.86864)
# 236  POINT (-70.66899 -33.44807)
# 237    POINT (88.32273 22.49692)
# 238  POINT (-43.22697 -22.92308)
# 239  POINT (-46.62697 -23.55673)
# 240  POINT (151.18323 -33.91807)
# 241    POINT (103.85387 1.29498)
# 242   POINT (114.18306 22.30693)
#
# [10 rows x 120 columns]

# %% [markdown]
# ### View coordinate of one city
# Where is Vatican City on this map?

# %%
print(cities['geometry'][0])
# Out:
# POINT (12.45338654497177 41.90328217996012)

# %% [markdown]
# #### Location of Singapore

# %%
print(cities['geometry'][241])
# Out:
# POINT (103.853874819099 1.294979325105942)

# %%
two_cities = cities.iloc[[0, 241]]

two_cities
# Out:
#      SCALERANK  NATSCALE  LABELRANK       FEATURECLA          NAME NAMEPAR  \
# 0            8        10          3  Admin-0 capital  Vatican City    None
# 241          0       600          0  Admin-0 capital     Singapore    None
#
#     NAMEALT  DIFFASCII     NAMEASCII  ADM0CAP  ... name_ja  name_ko  \
# 0      None          0  Vatican City      1.0  ...    バチカン   바티칸 시국
# 241    None          0     Singapore      1.0  ...  シンガポール     싱가포르
#
#           name_nl   name_pl        name_sv   name_tr        name_vi  \
# 0    Vaticaanstad   Watykan  Vatikanstaten   Vatikan  Thành Vatican
# 241     Singapore  Singapur      Singapore  Singapur      Singapore
#
#     wdid_score       ne_id                   geometry
# 0            4  1159127243  POINT (12.45339 41.90328)
# 241          4  1159151627  POINT (103.85387 1.29498)
#
# [2 rows x 120 columns]

# %% [markdown]
# #### Plotting the cities
# This is meaningless without a map

# %%
two_cities.plot(color = 'r')

plt.show()

# %% [markdown]
# #### Plotting the cities on a world map
# The plot method returns an axis object which can be used to plot the cities

# %%
ax = countries.plot(figsize=(12, 6))

two_cities.plot(ax = ax, color = 'r')

plt.show()

# %% [markdown]
# __A [Datasets](http://www.naturalearthdata.com/downloads/50m-physical-vectors/50m-rivers-lake-centerlines/) about rivers in the world__

# %% [markdown]
# ### Load and read another geospatial data of rivers

# %%
rivers = geopandas.read_file('zip://datasets/ne_50m_rivers_lake_centerlines.zip')

# %%
rivers.head()
# Out:
#    scalerank       featurecla      name  note  min_zoom name_alt  min_label  \
# 0          6  Lake Centerline      Kama  None       5.0     None        6.0
# 1          6            River      Kama  None       5.0     None        6.0
# 2          3  Lake Centerline      Abay  None       3.0     None        4.0
# 3          3  Lake Centerline  Al Furat  None       3.0     None        4.0
# 4          6  Lake Centerline   Alabama  None       5.0     None        6.0
#
#        name_en     label wikidataid  ...  name_pl          name_pt  name_ru  \
# 0         Kama      Kama     Q79082  ...     Kama         Rio Kama     Кама
# 1         Kama      Kama     Q79082  ...     Kama         Rio Kama     Кама
# 2  Lesser Abay      None   Q3501984  ...     None  Rio Lesser Abay     None
# 3    Euphrates  Al Furat     Q34589  ...   Eufrat     Rio Eufrates   Евфрат
# 4      Alabama   Alabama    Q558643  ...  Alabama      Rio Alabama  Алабама
#
#        name_sv name_tr       name_vi name_zh wdid_score       ne_id  \
# 0         Kama    None     Sông Kama     卡馬河          4  1159125905
# 1         Kama    None     Sông Kama     卡馬河          4  1159125917
# 2  Lesser Abay    None          None    None          2  1159125319
# 3       Eufrat   Fırat     Euphrates   幼发拉底河          5  1159125935
# 4         None    None  Sông Alabama   阿拉巴馬河          4  1159114961
#
#                                             geometry
# 0  LINESTRING (51.93713 55.70107, 51.88087 55.686...
# 1  LINESTRING (53.69385 58.20632, 53.67715 58.273...
# 2  LINESTRING (37.11301 11.85499, 37.15037 11.893...
# 3  LINESTRING (38.56119 35.86264, 38.36534 35.903...
# 4  MULTILINESTRING ((-86.52177 33.03212, -86.5209...
#
# [5 rows x 33 columns]

# %% [markdown]
# ### View, coordinates of one river

# %%
print(rivers['geometry'][0])
# Out:
# LINESTRING (51.9371337598152 55.70106609892139, 51.88086646731369 55.68625891701544, 51.82031249962222 55.69745514553858, 51.7476018274624 55.69366250841807, 51.6628417966117 55.60817291874525, 51.57871093775964 55.59943268477065, 51.51342773400279 55.58312409100404, 51.50854492161091 55.52948639548083, 51.48583984403365 55.49640534033426, 51.36914062543957 55.46796295772435, 51.21306254869774 55.50264985760492, 51.13452148447897 55.48273346527725, 51.07934570274205 55.46759674659262, 50.98022460947817 55.46637604371949, 50.83445217522774 55.45630956063775, 50.6883789060617 55.42011139502489, 50.4118652342932 55.40119049644431, 50.07802734358711 55.38112213757665, 49.82216796867687 55.33466217681809, 49.53222656260584 55.260614325191, 49.38232421848795 55.17182037990665, 49.24808475131027 55.11301870345045)

# %% [markdown]
# ## Plotting our different layers

# %% [markdown]
# ### Plot countries map
# We focus on the central parts of the world. We don't shade the countries either

# %%
ax = countries.plot(figsize=(15, 8))

ax.set(xlim=(-20, 120), ylim=(-40, 80))

plt.show()

# %%
ax = countries.plot(edgecolor = 'k', 
                    facecolor='none', 
                    figsize=(15, 8))

ax.set(xlim=(-20, 120), ylim=(-40, 80))

plt.show()

# %% [markdown]
# ## Plotting rivers on map

# %%
ax = countries.plot(edgecolor = 'k', 
                    facecolor='none', 
                    figsize=(15, 8))

rivers.plot(ax=ax)
ax.set(xlim=(-20, 120), ylim=(-40, 80))

plt.show()

# %% [markdown]
# ## Plottting rivers as well as cities

# %%
ax = countries.plot(edgecolor = 'k', 
                    facecolor='none', 
                    figsize=(15, 8))
rivers.plot(ax=ax)
cities.plot(ax=ax, color='red')

ax.set(xlim=(-20, 120), ylim=(-40, 80))

plt.show()
